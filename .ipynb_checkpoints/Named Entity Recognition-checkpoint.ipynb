# %%
# NLP Lecture @ Strive School - 21st July 2021
# NER update

'''
Since today we are exploring the world of natural language processing, we’ll deepen in the Named Entity Recognition technique: this is just one of the mechanisms that NLP embodies. The recognition of named entities as the process of automatic identification of the entities present in a text and consequent classification into predefined categories such as "person", "organization", "position" is a quite common activity and expect for English, trained models with spaCy offer few labels that could be improved through training.

Following the case study of this morning, try to emulate it in order to label all the brands present in the provided datasets, choosing the one you prefer OR trying to label all them and to train the model to recognize new different entities. The result should be twofold: the final model should be able to recognize brands that it has already seen, but already new ones.
The brands proposed in the dataset concern fashion, cars and food.
In order to test the accuracy of the model, test it with sentences and brands the model has never seen.

Sample of the dataset
---------------------
- Cate Blanchett in Armani Privé. Rating: 8. Concludes as a rare butterfly, or from Rorschach's Test, or from computerized axial tomography.
- I liked everything, recommend it! Another quality Xiaomi product...
- What is the price of that Fiat 500XL?

Info:
- Feel free to change or arrange a new dataset
- Try experimenting and tuning with the hyperparameters
- Feel free to use or change the code you've seen during the morning session
- TBD = To be done (from you!) :)

'''

# %%
# STEP 0 - PRE REQUISITES

# python -m spacy download en_core_web_lg

# TBD: Import libraries
import spacy
import random
from spacy.util import minibatch, compounding
from pathlib import Path
from spacy.training import Example

# TBD: Load preferred model
nlp= spacy.load('en_core_web_lg')

with open("food.txt") as file:
    dataset = file.read()

# TBD: Load the dataset and test it as-is

# %%
doc = nlp(dataset)
print("Entities:", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities: [('Italian', 'NORP'), ('first', 'ORDINAL'), ('Arrosticini', 'PERSON'), ('Alfredo', 'PERSON'), ('Naples', 'GPE'), ('Zaza', 'PERSON'), ('ApplePie', 'ORG'), ('Bologna', 'GPE'), ('Fiorentina Steak', 'PERSON'), ('Pineapple', 'ORG'), ('First', 'ORDINAL'), ('Bronte', 'PERSON'), ('Coca-cola', 'ORG'), ('Fanta', 'ORG'), ('Pepsi', 'ORG'), ('One', 'CARDINAL'), ('Sorrento', 'GPE'), ('Coffee\nBread', 'ORG'), ('Love', 'WORK_OF_ART'), ('Fatte', 'PERSON'), ('vedrai che il mondo poi ti', 'PERSON'), ('Pastiera', 'PERSON'), ('the United States', 'GPE'), ('Two', 'CARDINAL'), ('two', 'CARDINAL'), ('24 hours', 'TIME'), ('24', 'CARDINAL'), ('two hours', 'TIME')]

# %%
# STEP 1 - TRAIN DATA

# Prepare training data

# TBD: define all the entities by extracting the words and their indexes from the dataset
# expected format is the following:  ("sentence", {"entities": [0,10, "FOOD"]})


words = ['Ketchup','pasta','carrot','pizza','garlic','tomato sauce','basil',
         'carbonara','eggs','cheek fat','pan cakes','parmigiana','eggplant',
        'fettucine','heavy cream','polenta','risotto','espresso','arrosticini','spaghetti',
         'fiorentina steak','pecorino','maccherone',
        'neutella','amero','pistachio','coca-cola','wine','pastiera','watermelon','cappuccino',
        'ice cream','soup','lemon','chocolate',"pineapple"]

train_data = []

with open('food.txt') as file:
    dataset = file.readlines()
    for sentence in dataset:
        print('********')
        print('sentences:', sentence)
        print('********')
        sentence= sentence.lower()
        entities= []
        for word in words:
            word= word.lower()
            if word in sentence:
                start_index= sentence.index(word)
                end_index = len(word)+ start_index
                print('word:', word)
                print('************')
                print('start_index:', start_index)
                print('end_index:', end_index)
                pos = (start_index, end_index, 'FOOD')
                entities.append(pos)
        element = (sentence.rstrip('\n'), {'entities': entities})
        train_data.append(element)
        print('********')
        print('element:', element)
        print('********')
# Out:
# ********
# sentences: Give me carrot cake.
#
# ********
# word: carrot
# ************
# start_index: 8
# end_index: 14
# ********
# element: ('give me carrot cake.', {'entities': [(8, 14, 'FOOD')]})
# ********
# ********
# sentences: I love simple pizza margherita with tomato sauce and mozzarella.
#
# ********
# word: pizza
# ************
# start_index: 14
# end_index: 19
# word: tomato sauce
# ************
# start_index: 36
# end_index: 48
# ********
# element: ('i love simple pizza margherita with tomato sauce and mozzarella.', {'entities': [(14, 19, 'FOOD'), (36, 48, 'FOOD')]})
# ********
# ********
# sentences: I don't like pizza with garlic!
#
# ********
# word: pizza
# ************
# start_index: 13
# end_index: 18
# word: garlic
# ************
# start_index: 24
# end_index: 30
# ********
# element: ("i don't like pizza with garlic!", {'entities': [(13, 18, 'FOOD'), (24, 30, 'FOOD')]})
# ********
# ********
# sentences: I like pasta with homemade tomato sauce and basil.
#
# ********
# word: pasta
# ************
# start_index: 7
# end_index: 12
# word: tomato sauce
# ************
# start_index: 27
# end_index: 39
# word: basil
# ************
# start_index: 44
# end_index: 49
# ********
# element: ('i like pasta with homemade tomato sauce and basil.', {'entities': [(7, 12, 'FOOD'), (27, 39, 'FOOD'), (44, 49, 'FOOD')]})
# ********
# ********
# sentences: Always make carbonara with eggs and cheek lard!
#
# ********
# word: carbonara
# ************
# start_index: 12
# end_index: 21
# word: eggs
# ************
# start_index: 27
# end_index: 31
# ********
# element: ('always make carbonara with eggs and cheek lard!', {'entities': [(12, 21, 'FOOD'), (27, 31, 'FOOD')]})
# ********
# ********
# sentences: Don't mess with my carbonara!
#
# ********
# word: carbonara
# ************
# start_index: 19
# end_index: 28
# ********
# element: ("don't mess with my carbonara!", {'entities': [(19, 28, 'FOOD')]})
# ********
# ********
# sentences: Get your hands off my pancakes!
#
# ********
# ********
# element: ('get your hands off my pancakes!', {'entities': []})
# ********
# ********
# sentences: The original Italian "parmigiana" is done with eggplant, not zucchini.
#
# ********
# word: parmigiana
# ************
# start_index: 22
# end_index: 32
# word: eggplant
# ************
# start_index: 47
# end_index: 55
# ********
# element: ('the original italian "parmigiana" is done with eggplant, not zucchini.', {'entities': [(22, 32, 'FOOD'), (47, 55, 'FOOD')]})
# ********
# ********
# sentences: Never put pineapple in your pizza.
#
# ********
# word: pizza
# ************
# start_index: 28
# end_index: 33
# word: pineapple
# ************
# start_index: 10
# end_index: 19
# ********
# element: ('never put pineapple in your pizza.', {'entities': [(28, 33, 'FOOD'), (10, 19, 'FOOD')]})
# ********
# ********
# sentences: I would say that pineapple on a pizza could be oltrageous.
#
# ********
# word: pizza
# ************
# start_index: 32
# end_index: 37
# word: pineapple
# ************
# start_index: 17
# end_index: 26
# ********
# element: ('i would say that pineapple on a pizza could be oltrageous.', {'entities': [(32, 37, 'FOOD'), (17, 26, 'FOOD')]})
# ********
# ********
# sentences: I miss my mum's risotto!
#
# ********
# word: risotto
# ************
# start_index: 16
# end_index: 23
# ********
# element: ("i miss my mum's risotto!", {'entities': [(16, 23, 'FOOD')]})
# ********
# ********
# sentences: Espresso, what else?
#
# ********
# word: espresso
# ************
# start_index: 0
# end_index: 8
# ********
# element: ('espresso, what else?', {'entities': [(0, 8, 'FOOD')]})
# ********
# ********
# sentences: I don't like pizza with pineapple.
#
# ********
# word: pizza
# ************
# start_index: 13
# end_index: 18
# word: pineapple
# ************
# start_index: 24
# end_index: 33
# ********
# element: ("i don't like pizza with pineapple.", {'entities': [(13, 18, 'FOOD'), (24, 33, 'FOOD')]})
# ********
# ********
# sentences: Never put ketchup salsa in your pasta.
#
# ********
# word: ketchup
# ************
# start_index: 10
# end_index: 17
# word: pasta
# ************
# start_index: 32
# end_index: 37
# ********
# element: ('never put ketchup salsa in your pasta.', {'entities': [(10, 17, 'FOOD'), (32, 37, 'FOOD')]})
# ********
# ********
# sentences: In heaven, after antipasti, the first course will be pasta.
#
# ********
# word: pasta
# ************
# start_index: 53
# end_index: 58
# ********
# element: ('in heaven, after antipasti, the first course will be pasta.', {'entities': [(53, 58, 'FOOD')]})
# ********
# ********
# sentences: Arrosticini are not kebabs!!!
#
# ********
# word: arrosticini
# ************
# start_index: 0
# end_index: 11
# ********
# element: ('arrosticini are not kebabs!!!', {'entities': [(0, 11, 'FOOD')]})
# ********
# ********
# sentences: Alfredo did not invent any pasta!
#
# ********
# word: pasta
# ************
# start_index: 27
# end_index: 32
# ********
# element: ('alfredo did not invent any pasta!', {'entities': [(27, 32, 'FOOD')]})
# ********
# ********
# sentences: Don't touch my fettuccine.
#
# ********
# ********
# element: ("don't touch my fettuccine.", {'entities': []})
# ********
# ********
# sentences: Hey! Avoid heavy cream and bacon in the carbonara recipe.
#
# ********
# word: carbonara
# ************
# start_index: 40
# end_index: 49
# word: heavy cream
# ************
# start_index: 11
# end_index: 22
# ********
# element: ('hey! avoid heavy cream and bacon in the carbonara recipe.', {'entities': [(40, 49, 'FOOD'), (11, 22, 'FOOD')]})
# ********
# ********
# sentences: Polenta warms my heart!
#
# ********
# word: polenta
# ************
# start_index: 0
# end_index: 7
# ********
# element: ('polenta warms my heart!', {'entities': [(0, 7, 'FOOD')]})
# ********
# ********
# sentences: TiramisÃ¹ is just the best cake.
#
# ********
# ********
# element: ('tiramisã¹ is just the best cake.', {'entities': []})
# ********
# ********
# sentences: All you need is love. But a little chocolate now and then doesn't hurt.
#
# ********
# word: chocolate
# ************
# start_index: 35
# end_index: 44
# ********
# element: ("all you need is love. but a little chocolate now and then doesn't hurt.", {'entities': [(35, 44, 'FOOD')]})
# ********
# ********
# sentences: Best Pizza was born in Naples
#
# ********
# word: pizza
# ************
# start_index: 5
# end_index: 10
# ********
# element: ('best pizza was born in naples', {'entities': [(5, 10, 'FOOD')]})
# ********
# ********
# sentences: I like bucatini all'amatriciana (the real one)
#
# ********
# ********
# element: ("i like bucatini all'amatriciana (the real one)", {'entities': []})
# ********
# ********
# sentences: The Zaza's ApplePie is unmatched
#
# ********
# ********
# element: ("the zaza's applepie is unmatched", {'entities': []})
# ********
# ********
# sentences: Spaghetti "Bolognese" does not exist!!!
#
# ********
# word: spaghetti
# ************
# start_index: 0
# end_index: 9
# ********
# element: ('spaghetti "bolognese" does not exist!!!', {'entities': [(0, 9, 'FOOD')]})
# ********
# ********
# sentences: Spaghetti bolognese doesnâ€™t exist in Bologna.
#
# ********
# word: spaghetti
# ************
# start_index: 0
# end_index: 9
# ********
# element: ('spaghetti bolognese doesnâ€™t exist in bologna.', {'entities': [(0, 9, 'FOOD')]})
# ********
# ********
# sentences: How could be a world without Fiorentina Steak?
#
# ********
# word: fiorentina steak
# ************
# start_index: 29
# end_index: 45
# ********
# element: ('how could be a world without fiorentina steak?', {'entities': [(29, 45, 'FOOD')]})
# ********
# ********
# sentences: I do love cooking sous vide, but only when I have plenty of time!
#
# ********
# ********
# element: ('i do love cooking sous vide, but only when i have plenty of time!', {'entities': []})
# ********
# ********
# sentences: It's not bistecca unless it's rare.
#
# ********
# ********
# element: ("it's not bistecca unless it's rare.", {'entities': []})
# ********
# ********
# sentences: Pineapple does not belong to pizza.
#
# ********
# word: pizza
# ************
# start_index: 29
# end_index: 34
# word: pineapple
# ************
# start_index: 0
# end_index: 9
# ********
# element: ('pineapple does not belong to pizza.', {'entities': [(29, 34, 'FOOD'), (0, 9, 'FOOD')]})
# ********
# ********
# sentences: I love my mouse's lemon cheesecake.
#
# ********
# word: lemon
# ************
# start_index: 18
# end_index: 23
# ********
# element: ("i love my mouse's lemon cheesecake.", {'entities': [(18, 23, 'FOOD')]})
# ********
# ********
# sentences: in carbonara, pecorino is used.
#
# ********
# word: carbonara
# ************
# start_index: 3
# end_index: 12
# word: pecorino
# ************
# start_index: 14
# end_index: 22
# ********
# element: ('in carbonara, pecorino is used.', {'entities': [(3, 12, 'FOOD'), (14, 22, 'FOOD')]})
# ********
# ********
# sentences: Spoiler alert, peperoni are a vegetables types
#
# ********
# ********
# element: ('spoiler alert, peperoni are a vegetables types', {'entities': []})
# ********
# ********
# sentences: Not by bread alone!
#
# ********
# ********
# element: ('not by bread alone!', {'entities': []})
# ********
# ********
# sentences: Get your hands off my pastries
#
# ********
# ********
# element: ('get your hands off my pastries', {'entities': []})
# ********
# ********
# sentences: Take away everything, but not my Nutella
#
# ********
# ********
# element: ('take away everything, but not my nutella', {'entities': []})
# ********
# ********
# sentences: Maccherone, you provoked me and now I'll eat you
#
# ********
# word: maccherone
# ************
# start_index: 0
# end_index: 10
# ********
# element: ("maccherone, you provoked me and now i'll eat you", {'entities': [(0, 10, 'FOOD')]})
# ********
# ********
# sentences: What more could you want? An amaro Lucano
#
# ********
# ********
# element: ('what more could you want? an amaro lucano', {'entities': []})
# ********
# ********
# sentences: First pancake never turns out the best
#
# ********
# ********
# element: ('first pancake never turns out the best', {'entities': []})
# ********
# ********
# sentences: Not all donuts come with a hole
#
# ********
# ********
# element: ('not all donuts come with a hole', {'entities': []})
# ********
# ********
# sentences: A glass of wine a day keeps the doctor away
#
# ********
# word: wine
# ************
# start_index: 11
# end_index: 15
# ********
# element: ('a glass of wine a day keeps the doctor away', {'entities': [(11, 15, 'FOOD')]})
# ********
# ********
# sentences: Good wine makes good blood
#
# ********
# word: wine
# ************
# start_index: 5
# end_index: 9
# ********
# element: ('good wine makes good blood', {'entities': [(5, 9, 'FOOD')]})
# ********
# ********
# sentences: When pigs are butchered, nothing is wasted
#
# ********
# ********
# element: ('when pigs are butchered, nothing is wasted', {'entities': []})
# ********
# ********
# sentences: Don't let the farmer know how good is the pear with the cheese
#
# ********
# ********
# element: ("don't let the farmer know how good is the pear with the cheese", {'entities': []})
# ********
# ********
# sentences: An apple a day keeps the doctor away
#
# ********
# ********
# element: ('an apple a day keeps the doctor away', {'entities': []})
# ********
# ********
# sentences: Whoever has bread does not have teeth and whoever has teeth does not have bread
#
# ********
# ********
# element: ('whoever has bread does not have teeth and whoever has teeth does not have bread', {'entities': []})
# ********
# ********
# sentences: The best pistachio comes from Bronte
#
# ********
# word: pistachio
# ************
# start_index: 9
# end_index: 18
# ********
# element: ('the best pistachio comes from bronte', {'entities': [(9, 18, 'FOOD')]})
# ********
# ********
# sentences: Who doesn't like chocolate has something to hide
#
# ********
# word: chocolate
# ************
# start_index: 17
# end_index: 26
# ********
# element: ("who doesn't like chocolate has something to hide", {'entities': [(17, 26, 'FOOD')]})
# ********
# ********
# sentences: Coca-cola, Fanta or Pepsi?
#
# ********
# word: coca-cola
# ************
# start_index: 0
# end_index: 9
# ********
# element: ('coca-cola, fanta or pepsi?', {'entities': [(0, 9, 'FOOD')]})
# ********
# ********
# sentences: If it's not soup, it's wet bread
#
# ********
# word: soup
# ************
# start_index: 12
# end_index: 16
# ********
# element: ("if it's not soup, it's wet bread", {'entities': [(12, 16, 'FOOD')]})
# ********
# ********
# sentences: Garlic is good for blood pressure
#
# ********
# word: garlic
# ************
# start_index: 0
# end_index: 6
# ********
# element: ('garlic is good for blood pressure', {'entities': [(0, 6, 'FOOD')]})
# ********
# ********
# sentences: Watermelon contains a lot of water
#
# ********
# word: watermelon
# ************
# start_index: 0
# end_index: 10
# ********
# element: ('watermelon contains a lot of water', {'entities': [(0, 10, 'FOOD')]})
# ********
# ********
# sentences: I have breakfast with a croissant and cappuccino
#
# ********
# word: cappuccino
# ************
# start_index: 38
# end_index: 48
# ********
# element: ('i have breakfast with a croissant and cappuccino', {'entities': [(38, 48, 'FOOD')]})
# ********
# ********
# sentences: One cherry leads to the other
#
# ********
# ********
# element: ('one cherry leads to the other', {'entities': []})
# ********
# ********
# sentences: Throw the pasta into a pan full of salted boiling water
#
# ********
# word: pasta
# ************
# start_index: 10
# end_index: 15
# ********
# element: ('throw the pasta into a pan full of salted boiling water', {'entities': [(10, 15, 'FOOD')]})
# ********
# ********
# sentences: Ketchup is not a substitute for tomato sauce
#
# ********
# word: ketchup
# ************
# start_index: 0
# end_index: 7
# word: tomato sauce
# ************
# start_index: 32
# end_index: 44
# ********
# element: ('ketchup is not a substitute for tomato sauce', {'entities': [(0, 7, 'FOOD'), (32, 44, 'FOOD')]})
# ********
# ********
# sentences: This is the icing on the cake
#
# ********
# ********
# element: ('this is the icing on the cake', {'entities': []})
# ********
# ********
# sentences: Sorrento lemons are famous all over the world
#
# ********
# word: lemon
# ************
# start_index: 9
# end_index: 14
# ********
# element: ('sorrento lemons are famous all over the world', {'entities': [(9, 14, 'FOOD')]})
# ********
# ********
# sentences: When you are sad, the best solution is to eat tiramisu
#
# ********
# ********
# element: ('when you are sad, the best solution is to eat tiramisu', {'entities': []})
# ********
# ********
# sentences: In carbonara, bacon is not used, but pig cheek
#
# ********
# word: carbonara
# ************
# start_index: 3
# end_index: 12
# ********
# element: ('in carbonara, bacon is not used, but pig cheek', {'entities': [(3, 12, 'FOOD')]})
# ********
# ********
# sentences: Strawberries and cream are a winning team
#
# ********
# ********
# element: ('strawberries and cream are a winning team', {'entities': []})
# ********
# ********
# sentences: Pizza margherita is the most famous in the world
#
# ********
# word: pizza
# ************
# start_index: 0
# end_index: 5
# ********
# element: ('pizza margherita is the most famous in the world', {'entities': [(0, 5, 'FOOD')]})
# ********
# ********
# sentences: All you need is ~love~ Coffee
#
# ********
# ********
# element: ('all you need is ~love~ coffee', {'entities': []})
# ********
# ********
# sentences: Bread and jam from snack
#
# ********
# ********
# element: ('bread and jam from snack', {'entities': []})
# ********
# ********
# sentences: You never give up on ice cream.
#
# ********
# word: ice cream
# ************
# start_index: 21
# end_index: 30
# ********
# element: ('you never give up on ice cream.', {'entities': [(21, 30, 'FOOD')]})
# ********
# ********
# sentences: Life is like a barbecue. There is always someone sweating all day for others to sit and eat.
#
# ********
# ********
# element: ('life is like a barbecue. there is always someone sweating all day for others to sit and eat.', {'entities': []})
# ********
# ********
# sentences: There is nothing that can't be solved with a smile and a good meal.
#
# ********
# ********
# element: ("there is nothing that can't be solved with a smile and a good meal.", {'entities': []})
# ********
# ********
# sentences: Those who only drink water have a secret to hide.
#
# ********
# ********
# element: ('those who only drink water have a secret to hide.', {'entities': []})
# ********
# ********
# sentences: Love without a kiss is like pizza without cheese.
#
# ********
# word: pizza
# ************
# start_index: 28
# end_index: 33
# ********
# element: ('love without a kiss is like pizza without cheese.', {'entities': [(28, 33, 'FOOD')]})
# ********
# ********
# sentences: A circle cut into triangles, inside a square: Pizza is the nirvana of Pythagoras!
#
# ********
# word: pizza
# ************
# start_index: 46
# end_index: 51
# ********
# element: ('a circle cut into triangles, inside a square: pizza is the nirvana of pythagoras!', {'entities': [(46, 51, 'FOOD')]})
# ********
# ********
# sentences: Fatte 'na pizza c'a pummarola 'ncoppa, vedrai che il mondo poi ti sorriderÃ .
#
# ********
# word: pizza
# ************
# start_index: 10
# end_index: 15
# ********
# element: ("fatte 'na pizza c'a pummarola 'ncoppa, vedrai che il mondo poi ti sorriderã\xa0.", {'entities': [(10, 15, 'FOOD')]})
# ********
# ********
# sentences: When the moon hits your eye like a big pizza pie, that's amore!
#
# ********
# word: pizza
# ************
# start_index: 39
# end_index: 44
# ********
# element: ("when the moon hits your eye like a big pizza pie, that's amore!", {'entities': [(39, 44, 'FOOD')]})
# ********
# ********
# sentences: You say that beauty will save the world because you have not tasted the Neapolitan Pastiera.
#
# ********
# word: pastiera
# ************
# start_index: 83
# end_index: 91
# ********
# element: ('you say that beauty will save the world because you have not tasted the neapolitan pastiera.', {'entities': [(83, 91, 'FOOD')]})
# ********
# ********
# sentences: The best way not to have unpleasant smells in the kitchen: eat out.
#
# ********
# ********
# element: ('the best way not to have unpleasant smells in the kitchen: eat out.', {'entities': []})
# ********
# ********
# sentences: I went to a Bio restaurant and the waiter told me all about his life.
#
# ********
# ********
# element: ('i went to a bio restaurant and the waiter told me all about his life.', {'entities': []})
# ********
# ********
# sentences: There is more complicity between me and the Nutella than between certain couples at the restaurant fixed on their cell phones.
#
# ********
# ********
# element: ('there is more complicity between me and the nutella than between certain couples at the restaurant fixed on their cell phones.', {'entities': []})
# ********
# ********
# sentences: In the United States the food is really bad. In some restaurants they even bring you the prognosis with the bill.
#
# ********
# ********
# element: ('in the united states the food is really bad. in some restaurants they even bring you the prognosis with the bill.', {'entities': []})
# ********
# ********
# sentences: Two beers or not two beers: that is the passion.
#
# ********
# ********
# element: ('two beers or not two beers: that is the passion.', {'entities': []})
# ********
# ********
# sentences: How can you have fun at a party where the beers are warm and the women are cold?
#
# ********
# ********
# element: ('how can you have fun at a party where the beers are warm and the women are cold?', {'entities': []})
# ********
# ********
# sentences: 24 hours in a day, 24 beers in a box. Coincidence?
#
# ********
# ********
# element: ('24 hours in a day, 24 beers in a box. coincidence?', {'entities': []})
# ********
# ********
# sentences: Drinking non-alcoholic beer is like listening a porn movie on the radio.
#
# ********
# ********
# element: ('drinking non-alcoholic beer is like listening a porn movie on the radio.', {'entities': []})
# ********
# ********
# sentences: Jesus turned water into wine. No wonder twelve disciples followed him everywhere.
#
# ********
# word: wine
# ************
# start_index: 24
# end_index: 28
# ********
# element: ('jesus turned water into wine. no wonder twelve disciples followed him everywhere.', {'entities': [(24, 28, 'FOOD')]})
# ********
# ********
# sentences: Those who don't like wine, God take away the water.
#
# ********
# word: wine
# ************
# start_index: 21
# end_index: 25
# ********
# element: ("those who don't like wine, god take away the water.", {'entities': [(21, 25, 'FOOD')]})
# ********
# ********
# sentences: Reality is an illusion that occurs because of the lack of wine.
#
# ********
# word: wine
# ************
# start_index: 58
# end_index: 62
# ********
# element: ('reality is an illusion that occurs because of the lack of wine.', {'entities': [(58, 62, 'FOOD')]})
# ********
# ********
# sentences: The best thing about wine is that, for two hours, your problems are someone else's.
# ********
# word: wine
# ************
# start_index: 21
# end_index: 25
# ********
# element: ("the best thing about wine is that, for two hours, your problems are someone else's.", {'entities': [(21, 25, 'FOOD')]})
# ********

# %%
# STEP 1 - TRAIN DATA

# Prepare training data

# TBD: define all the entities by extracting the words and their indexes from the dataset
# expected format is the following:  ("sentence", {"entities": [0,10, "FOOD"]})


words = [food=['Ketchup','pasta','carrot','pizza','garlic','tomato sauce','basil',
         'carbonara','eggs','cheek fat','pan cakes','parmigiana','eggplant',
        'fettucine','heavy cream','polenta','risotto','espresso','arrosticini','spaghetti',
         'fiorentina steak','pecorino','maccherone',
        'neutella','amero','pistachio','coca-cola','wine','pastiera','watermelon','cappuccino',
        'ice cream','soup','lemon','chocolate',"pineapple"],
         Organisation=['samsung','apple','blackberry','xaiomi','huawei','iphone','nokia','redmi','sony',
                      'lg',]
         

train_data = []

with open('food.txt') as file:
    dataset = file.readlines()
    for sentence in dataset:
        print('********')
        print('sentences:', sentence)
        print('********')
        sentence= sentence.lower()
        entities= []
        for unit in words:
         for word in unit:
                 
            word= word.lower()
            if word in sentence:
                start_index= sentence.index(word)
                end_index = len(word)+ start_index
                print('word:', word)
                print('************')
                print('start_index:', start_index)
                print('end_index:', end_index)
                pos = (start_index, end_index, 'unit')
                entities.append(pos)
        element = (sentence.rstrip('\n'), {'entities': entities})
        train_data.append(element)
        print('********')
        print('element:', element)
        print('********')

# %%
         
        
# STEP 2 - UPDATE MODEL

# TBD: load the needed pipeline
# ner = nlp.get_pipe('ner')
# for _, annotations in train_data:
#     for ent in annotations.get('entities'):
#         ner.add_label(ent[2])
        
# ner.add_label('FOOD')

# TBD: define the annotations

# TBD: train the model



pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]



# TBD: define the number of iterations, the batch size and the drop according to your experience or using an empirical value
# Train model
with nlp.disable_pipes(*unaffected_pipes):
    for iteration in range(30):
        print("Iteration #" + str(iteration))

        # Data shuffle for each iteration
        random.shuffle(train_data)
        losses = {}
        batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
        for batch in spacy.util.minibatch(train_data, size=3):
            for text, annotations in batch:
                # Create an Example object
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                # Update the model
                nlp.update([example], losses=losses, drop=0.1)
        print("Losses:", losses)

# Save the model
output_dir= path('/ner/')
nlp.to_disk(output_dir)
print('saved')
# TBD:
# Out:
# Iteration #0

# %%
# STEP 3 - TEST THE UPDATED MODEL

# Load updated model
nlp_updated = spacy.load(output_dir)

# TBD: test with a old sentence
doc= nlp_updated('Alfredo did not invent any pasta!')
print("entities:", [(ent.text, ent.label_) for ent in doc.ents])

# TBD: test with a new sentence and an old brand
doc= nlp_updated('I dont like spaghetti with mayo')
print("entities:", [(ent.text, ent.label_) for ent in doc.ents])

# TBD: test with a new sentence and a new brand
doc= nlp_updated('burger with cheese is good')
print("entities:", [(ent.text, ent.label_) for ent in doc.ents])
